# %% [markdown]
# # Correlación

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer

breast_cancer = load_breast_cancer()
data = breast_cancer.data
features = breast_cancer.feature_names
df = pd.DataFrame(data, columns = features)
df
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
df_small = df.iloc[:,:6]
correlation_mat = df_small.corr()
sns.heatmap(correlation_mat, annot = True)
plt.show()

# %% [markdown]
# Convirtiendo a vector

# %%
corr_values=correlation_mat.unstack()
corr_values
# Out:
# mean radius       mean radius         1.000000
#                   mean texture        0.323782
#                   mean perimeter      0.997855
#                   mean area           0.987357
#                   mean smoothness     0.170581
#                   mean compactness    0.506124
# mean texture      mean radius         0.323782
#                   mean texture        1.000000
#                   mean perimeter      0.329533
#                   mean area           0.321086
#                   mean smoothness    -0.023389
#                   mean compactness    0.236702
# mean perimeter    mean radius         0.997855
#                   mean texture        0.329533
#                   mean perimeter      1.000000
#                   mean area           0.986507
#                   mean smoothness     0.207278
#                   mean compactness    0.556936
# mean area         mean radius         0.987357
#                   mean texture        0.321086
# ...

# %% [markdown]
# Escogemos el tipo de algorimot para ordenar nuestro vector.

# %%
sorted_pairs = corr_values.sort_values(kind="quicksort")

# %% [markdown]
# ## Graficando la Correlación con seaborn

# %%
sns.pairplot(df_small)

# %% [markdown]
# ## Graficando la Correlación con matplotlib

# %%
negative_pairs = sorted_pairs[sorted_pairs < 0]
corr = df_small.corr()
sns.set()
cols = ['worst texture', 'concave points error', 
        'perimeter error',
        'mean compactness', 
        'worst symmetry',
        'mean radius', 
        'mean area']
sns.pairplot(df[cols], size = 2.5)
plt.show();
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=2fc7c785-41cd-4295-8d30-2962103ea22b' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
