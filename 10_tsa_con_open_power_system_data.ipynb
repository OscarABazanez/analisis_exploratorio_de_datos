# %% [markdown]
# # TSA con Open Power System Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
url = 'https://raw.githubusercontent.com/terranigmark/curso-analisis-exploratorio-datos-platzi/main/df_power.csv'
df_power_system = pd.read_csv(url, error_bad_lines=False)
df_power_system.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Consumption', 'Wind', 'Solar', 'Wind+Solar'], dtype='object')

# %% [markdown]
# ## Convertir object a datatime

# %%
df_power_system['Date'] = pd.to_datetime(df_power_system['Date'])
df_power_system = df_power_system.set_index('Date')
df_power_system
# Out:
#             Unnamed: 0  Consumption     Wind   Solar  Wind+Solar
# Date
# 2006-01-01           0   1069.18400      NaN     NaN         NaN
# 2006-01-02           1   1380.52100      NaN     NaN         NaN
# 2006-01-03           2   1442.53300      NaN     NaN         NaN
# 2006-01-04           3   1457.21700      NaN     NaN         NaN
# 2006-01-05           4   1477.13100      NaN     NaN         NaN
# ...                ...          ...      ...     ...         ...
# 2017-12-27        4378   1263.94091  394.507  16.530     411.037
# 2017-12-28        4379   1299.86398  506.424  14.162     520.586
# 2017-12-29        4380   1295.08753  584.277  29.854     614.131
# 2017-12-30        4381   1215.44897  721.247   7.467     728.714
# 2017-12-31        4382   1107.11488  721.176  19.980     741.156
#
# [4383 rows x 5 columns]

# %% [markdown]
# ## Agregando columnas con ano, mes y nombre de los dias laborales

# %%
df_power_system['Year'] = df_power_system.index.year
df_power_system['Month'] = df_power_system.index.month
df_power_system['Weekday Name'] = df_power_system.index.day_name()
df_power_system.head()
# Out:
#             Unnamed: 0  Consumption  Wind  Solar  Wind+Solar  Year  Month  \
# Date
# 2006-01-01           0     1069.184   NaN    NaN         NaN  2006      1
# 2006-01-02           1     1380.521   NaN    NaN         NaN  2006      1
# 2006-01-03           2     1442.533   NaN    NaN         NaN  2006      1
# 2006-01-04           3     1457.217   NaN    NaN         NaN  2006      1
# 2006-01-05           4     1477.131   NaN    NaN         NaN  2006      1
#
#            Weekday Name
# Date
# 2006-01-01       Sunday
# 2006-01-02       Monday
# 2006-01-03      Tuesday
# 2006-01-04    Wednesday
# 2006-01-05     Thursday

# %% [markdown]
# # VIsuzalización de los datos

# %%
df_power_system['Consumption'].plot(linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
cols_to_plot = ['Consumption', 'Solar', 'Wind']
axes = df_power_system[cols_to_plot].plot(
    marker = '.',
    alpha = 0.5,
    linestyle ='None',
    figsize = (14, 6),
    subplots = True
)
